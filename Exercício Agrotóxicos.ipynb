# %%
import pandas as pd
import numpy as np
import seaborn as srn

# %%
data=pd.read_excel("C:/Users/FLAVIA/Downloads/Reclassificação ANVISA AGROTÓXICOS -Excel.xlsx")

# %%
print(data.shape)
# Out:
# (1942, 20)

# %%
print(data.columns)
# Out:
# Index(['código', 'Razão Social',
#        'Cadastro Nacional da Pessoa Jurídica (CNPJ):', 'Marca Comercial',
#        'Número de Processo ANVISA', 'Número de Registro no MAPA/IBAMA',
#        'Finalidade de Uso:',
#        'Informar o tipo de produto de Uso Agrícola da sua empresa:',
#        'Forma de Apresentação OU Tipo de Formulação',
#        'Classificação toxicológica já registrada',
#        'Qual a nova Classificação Toxicológica para o produto da sua empresa?',
#        'Classificação Toxicológica para a DL50 Oral:',
#        'Classificação Toxicológica para a DL50 cutânea:',
#        'Classificação Toxicológica para a CL50 inalatória:',
#        'Categorização: irritação dermica', 'Categorização:irritação ocular',
#        'Categorização:sensibilização dermica',
#        'Categorização:sensiblização respiratória',
#        'Qual o resultado no teste de AMES?',
#        'Qual o resultado no teste do MICRONÚCLEO?'],
#       dtype='object')

# %%
 print(data.sort_values('Marca Comercial'))
# Out:
#       código                                     Razão Social  \
# 1223    1224                                        NORTOX SA
# 1287    1288       NUFARM INDUSTRIA QUIMICA E FARMACEUTICA SA
# 145      146                            Alamos do Brasil Ltda
# 997      998  Genbra Distribuidora de Produtos Agricolas Ltda
# 608      609                                     CCAB AGRO SA
# ...      ...                                              ...
# 1351    1352                           Ouro Fino Quimica S.A.
# 1004    1005                    Helm do Brasil Mercantil Ltda
# 1269    1270                                        NORTOX SA
# 579      580   BIO SOJA INDUSTRIAS QUIMICAS E BIOLOGICAS LTDA
# 580      581   BIO SOJA INDUSTRIAS QUIMICAS E BIOLOGICAS LTDA
#
#      Cadastro Nacional da Pessoa Jurídica (CNPJ):            Marca Comercial  \
# 1223                               75263400000199        2,4 D NORTOX COTTON
# ...

# %%
## len siginifica contar e unique valores unicos
## Quantos agrotoxicos são cadastrado no IBAMA?
len(data['Número de Registro no MAPA/IBAMA'].unique())
# Out:
# 1928

# %%
len(data.columns)
# Out:
# 20

# %%
##quantos produtos registrados
len(data.loc[data['Classificação toxicológica já registrada']
# Out:
#   File "C:\Users\FLAVIA\AppData\Local\Temp/ipykernel_22348/1196415852.py", line 2
#     len(data.loc[data['Classificação toxicológica já registrada']
#                                                                  ^
# SyntaxError: unexpected EOF while parsing

# %%
# quantas são letais categoria

# %%
len(data.loc[data['Classificação toxicológica já registrada']==1,['Classificação toxicológica já registrada']])
# Out:
# 0

# %%
pd.read_csv("C:/Users/FLAVIA/repor/pythonProject/desmatamento_municipio.csv")
# Out:
#         ano  id_municipio  area  desmatado  incremento  floresta  nuvem  \
# 0      2000       1100015  7137     1761.1         NaN    3639.6    0.0
# 1      2001       1100015  7137     1834.2        73.1    3566.5    0.0
# 2      2002       1100015  7137     1948.9       114.7    3451.8    0.0
# 3      2003       1100015  7137     2014.9        66.0    3385.8    0.0
# 4      2004       1100015  7137     2092.0        77.1    3308.7    0.0
# ...     ...           ...   ...        ...         ...       ...    ...
# 15955  2016       5108956  5277     2393.4        18.4    2864.0    0.0
# 15956  2017       5108956  5277     2414.3        21.0    2843.1    0.0
# 15957  2018       5108956  5277     2428.2        17.3    2829.2    0.0
# 15958  2019       5108956  5277     2468.2        40.0    2789.2    0.0
# 15959  2020       5108956  5277     2491.2        23.0    2766.2    0.0
#
#        nao_observado  nao_floresta  hidrografia
# 0                6.1        1708.0         22.2
# ...

# %%
print(data.columns())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22348/2732700449.py in <module>
# ----> 1 print(data.columns())
#
# TypeError: 'Index' object is not callable
